# %%
import os
import sys
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('stroopdata.csv')
data.head()
# Out:
#    Congruent  Incongruent
# 0     12.079       19.278
# 1     16.791       18.741
# 2      9.564       21.214
# 3      8.630       15.687
# 4     14.669       22.803

# %%
sd1 =data.describe()
sd2 = np.std(data)
sd1, sd2
# Out:
# (       Congruent  Incongruent
#  count  24.000000    24.000000
#  mean   14.051125    22.015917
#  std     3.559358     4.797057
#  min     8.630000    15.687000
#  25%    11.895250    18.716750
#  50%    14.356500    21.017500
#  75%    16.200750    24.051500
#  max    22.328000    35.255000, Congruent      3.484416
#  Incongruent    4.696055
#  dtype: float64)

# %% [markdown]
# * The mean time to name then Congruent words ($\mu_1$) = 14.0511
# * The mean time to name then Incongruent words ($\mu_2$) = 22.0159
# * The standard deviation of Congruent words sample is 3.5593, which is less than the  the standard deviation of Congruent words sample is, 4.7970, indicating that Congruent word sample is less variable.

# %%
import scipy
scipy.stats.skew(data.Congruent)
# Out:
# 0.3903776149050634

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
scipy.stats.skew(data.Incongruent)
# Out:
# 1.4491357281474857

# %%
sns.set_style('darkgrid')
h1 = plt.hist(data.Congruent, bins = 20, ec = 'red')

# %%
sns.set_style('white')
h1 = plt.hist(data.Incongruent, bins = 20, range=None, 
              normed=False, weights=None, cumulative=False,
              bottom=None, histtype='bar', align='mid', 
              orientation='vertical', rwidth=None,
              log=False, color='red', label='Incongruent', stacked=False,
              hold=None, data=None, ec= 'blue')
plt.xlabel('Incongruent word name time (s)', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.title('HIstogram', fontsize=15)
plt.yticks(range(0,5,1),fontsize = 13) 
plt.show()

# %%
sns.set_style('white')
h2 = plt.hist(data.Congruent, bins = 20, range=None, 
              normed=False, weights=None, cumulative=False,
              bottom=None, histtype='bar', align='mid', 
              orientation='vertical', rwidth=None,
              log=False, color='Blue', label='Congruent', stacked=False,
              hold=None, data=None, ec = 'red')
plt.xlabel('Congruent word name time (s)', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.title('Histogram', fontsize=15)
plt.yticks(range(0,5,1),fontsize = 13) 
plt.show()

# %%
sns.set_style('darkgrid')
h1 = sns.distplot(data.Congruent, bins = 15, norm_hist=True, color = "red")

# %%
sns.set_style('darkgrid')
h2 = sns.distplot(data.Incongruent, bins = 10)

# %%
h2 = sns.distplot(data.Incongruent, bins = 10)
h1 = sns.distplot(data.Congruent, bins = 15, norm_hist=True, color = "red")

# %%
b1 = data.plot.box()

# %%
b2 = plt.boxplot([data.Congruent, data.Incongruent])

# %%
#b2 = sns.boxplot(data = data, x = "Congruent", y= 'Incongruent' )

# %%
#j = sns.jointplot(data = data, x = "Congruent", y = "Incongruent", kind = 'hex')

# %%
#plt.rcParams['figure.figsize'] = 6,4
s1 = sns.lmplot(data = data, x = "Congruent", y= 'Incongruent')

# %%
sns.set_style('white')
plt.scatter(data.Congruent, data.Incongruent, c= "Red")
plt.xlabel('Congruent word time', fontsize=15)
plt.ylabel('Incongruent word time', fontsize=15)
plt.title('Scatter Diagram', fontsize=15)
plt.xticks(fontsize = 13) 
plt.yticks(range(15,39,3),fontsize = 13) 
plt.show()

# %%
r = scipy.stats.pearsonr(data.Congruent, data.Incongruent)
r
# Out:
# (0.35181952723213589, 0.091807664351758175)

# %%
#sns.FacetGrid(data, row = 'Congruent')

# %% [markdown]
# (4) Provide one or two visualizations that show the distribution of the sample data. Write one or two sentences noting what you observe about the plot or plots.

# %% [markdown]
# The two sets of data are visualized  using histogram and scatter plot shown in the fig. below. In both cases, candidates take different time to name the words. The scatter diagram shows no correlation between two sets of time.

# %%
from scipy.stats import ttest_ind
from scipy.stats import ttest_rel
from scipy.stats import f_oneway

# %%
t1 = ttest_ind(data.Congruent, data.Incongruent)
t1
# Out:
# Ttest_indResult(statistic=-6.5322505539032285, pvalue=4.5949489622951854e-08)

# %%
t2 = ttest_rel(data.Congruent, data.Incongruent)
t2
# Out:
# Ttest_relResult(statistic=-8.020706944109957, pvalue=4.1030005857111781e-08)

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/stats.html
# https://docs.scipy.org/doc/scipy/reference/stats.html
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.f_oneway.html#scipy.stats.f_oneway

# %% [markdown]
# * Fail to reject null hypothesis using t-test
# * Fail to reject null hypothesis using oneway f-test

# %%
f1 = f_oneway(data.Congruent, data.Incongruent)
f1
# Out:
# F_onewayResult(statistic=42.670297298969011, pvalue=4.5949489622952092e-08)

# %%
(5) Now, perform the statistical test and report the results. What is the confidence level and your critical statistic value? Do you reject the null hypothesis or fail to reject it? Come to a conclusion in terms of the experiment task. Did the results match up with your expectations?
# Out:
# Object `expectations` not found.

# %% [markdown]
# (5) Now, perform the statistical test and report the results. What is the confidence level and your critical statistic value? Do you reject the null hypothesis or fail to reject it? Come to a conclusion in terms of the experiment task. Did the results match up with your expectations

# %% [markdown]
# The two way relative t-test was done to test the above stated hypothesis. The t ststistic is found to be -8.0207. Based on the result, we reject null hypothesis.
